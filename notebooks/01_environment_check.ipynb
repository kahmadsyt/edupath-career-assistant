# %% [markdown]
# # 01 Environment Check
#
# Notebook ini digunakan untuk memvalidasi environment project EduPath Career Assistant.

# %%
import sys
import platform

print("Python version:", sys.version)
print("Platform:", platform.platform())
# Out:
# Python version: 3.10.20 | packaged by Anaconda, Inc. | (main, Jun 11 2026, 15:13:20) [MSC v.1942 64 bit (AMD64)]
# Platform: Windows-10-10.0.19045-SP0

# %%
import pandas as pd
import numpy as np
import sklearn
import streamlit
import nltk
import Sastrawi

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("scikit-learn:", sklearn.__version__)
print("streamlit:", streamlit.__version__)

print("Semua library utama berhasil di-import.")
# Out:
# pandas: 2.2.3
# numpy: 1.26.4
# scikit-learn: 1.5.2
# streamlit: 1.39.0
# Semua library utama berhasil di-import.

# %%
from pathlib import Path

ROOT_DIR = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()

print("Current directory:", Path.cwd())
print("Root candidate:", ROOT_DIR)
# Out:
# Current directory: D:\DATA-KAMIL\MATKUL\SEMESTER-1\DATA-MINING\TUGAS\UAS\edupath-career-assitant\notebooks
# Root candidate: D:\DATA-KAMIL\MATKUL\SEMESTER-1\DATA-MINING\TUGAS\UAS\edupath-career-assitant
